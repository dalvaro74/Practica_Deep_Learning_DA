# %% [markdown]
# # Resumen
# En este notebook vamos a partir del fichero original de airbnb (airbnb-listings.csv).
#
# Llevaremos a cabo la misma limpieza y seleccion de caracteristicas que hicimos en el caso de la practica del mudulo de Machine Learning.
#
# A esos datos una vez limpios y processados (Normalizacion, correlacion, outliers, categorizacion) le aplicaremos una red Neuronal tradicional para ver la bondad de ese modelo.

# %% [markdown]
# # Montar directorio Drive en colab
# En primer lugar vamos a montar el directorio de Drive para poder utilizar los ficheros de carga y para guardar de manera permanente otros ficheros de interes

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from os.path import join
ROOT = "/content/gdrive"
PROJ = "My Drive/Public/Practica_Deep_Learning_DA" 
PROJECT_PATH = join(ROOT, PROJ)

# %%
# !ls "/content/gdrive/My Drive/Public/Practica_Deep_Learning_DA"
# Out:
# 'Copia de regresion_Keras.ipynb'   nn_regresion_01.ipynb
#  data				   nn_regresion_02.ipynb
#  descarga_imagenes.ipyn		   practica_dl.ipynb
#  descarga_imagenes_OLD.old	   README.md
#  Explicacion_Practica.ipynb	   util
#  images

# %% [markdown]
# # Librerías y funciones
#
# Lo primero es cargar las librerías y funciones necesarias.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline

cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#0000FF'])

import warnings
warnings.filterwarnings('ignore')

#Para incluir en Colab las funciones del package utilidades creado por mi
from importlib.machinery import SourceFileLoader
import sys

missing_values_table = SourceFileLoader('missing_values_table', join(PROJECT_PATH, 'util/utilidades.py')).load_module()
change_cat_to_other = SourceFileLoader('change_cat_to_other', join(PROJECT_PATH, 'util/utilidades.py')).load_module()

sys.path.append('/content/gdrive/My\ Drive/Public/Practica_Deep_Learning_DA/util')
from missing_values_table import missing_values_table
from change_cat_to_other import change_cat_to_other

# %% [markdown]
# # Analisis exploratorio

# %% [markdown]
# ## Datos de entrada
#
# Cargamos los datos del fichero de airbnb reducido.
# Este fichero contiene 14870 observaciones y 89 variables

# %%
full_airbnb = pd.read_csv(join(PROJECT_PATH,'data/airbnb-listings.csv'),sep=';', decimal='.')

# %% [markdown]
# ## Outliers
# Antes de nada, vamos a hacer una pequeña limpieza de los outliers de precio,

# %%
full_airbnb = full_airbnb[(full_airbnb['Price']>10) & (full_airbnb['Price']<200)]

# %% [markdown]
# ## Limpieza general

# %%
missing_values_table(full_airbnb)
# Out:
# Your slelected dataframe has 89 columns.
# There are 58 columns that have missing values.
#                                 Missing Values  % of Total Values
# Has Availability                         14049              99.92
# Host Acceptance Rate                     14027              99.77
# Jurisdiction Names                       13858              98.56
# License                                  13734              97.68
# Square Feet                              13487              95.92
# Monthly Price                            10603              75.41
# Weekly Price                             10490              74.61
# Notes                                     8676              61.71
# Security Deposit                          8091              57.55
# Interaction                               6100              43.39
# Access                                    6022              42.83
# Cleaning Fee                              5755              40.93
# Transit                                   5298              37.68
# Neighborhood Overview                     5266              37.45
# Host About                                4981              35.43
# Neighbourhood                             4900              34.85
# House Rules                               4886              34.75
# Space                                     3683              26.19
# Host Neighbourhood                        3614              25.70
# Review Scores Value                       3028              21.54
# Review Scores Location                    3028              21.54
# Review Scores Checkin                     3024              21.51
# Review Scores Accuracy                    3013              21.43
# Review Scores Communication               3008              21.39
# Review Scores Cleanliness                 3007              21.39
# Review Scores Rating                      2994              21.29
# Last Review                               2865              20.38
# First Review                              2864              20.37
# Reviews per Month                         2864              20.37
# Thumbnail Url                             2560              18.21
# Medium Url                                2560              18.21
# XL Picture Url                            2560              18.21
# Host Response Rate                        1772              12.60
# Host Response Time                        1772              12.60
# Neighbourhood Group Cleansed               830               5.90
# Summary                                    551               3.92
# Zipcode                                    474               3.37
# State                                      119               0.85
# Amenities                                  103               0.73
# Market                                      56               0.40
# Bathrooms                                   51               0.36
# Beds                                        46               0.33
# Host Location                               40               0.28
# Bedrooms                                    25               0.18
# Picture Url                                 19               0.14
# Description                                  5               0.04
# Host Verifications                           5               0.04
# Calculated host listings count               4               0.03
# Host Since                                   3               0.02
# Host Total Listings Count                    3               0.02
# Host Listings Count                          3               0.02
# Host Picture Url                             3               0.02
# Host Thumbnail Url                           3               0.02
# Host Name                                    3               0.02
# City                                         2               0.01
# Name                                         1               0.01
# Country                                      1               0.01
# Features                                     1               0.01

# %% [markdown]
# Antes de llevar a cabo el split entre Trainintg y Test eliminamos las columnas que tenemos claro que no van a ser utiles para nuestro objetivo:
# 1. **Las que contienen URLs**: Listing Url: drop_url
# 2. **Los Ids y lo relativo al Scrape realizado**: drop_id_scrape
# 3. **Nombres y comentarios**:drop_comments
# 4. **Direcciones**: A la vista de la informacion que contienen las variables de direccion podemos dropear varias de ellas por diversos motivos (sin que tengamos que dividir previamente en Train Test). Demasiado genericas: City, State, Market, Smart Location, Country Code, Country, Jurisdiction Names. Demasiado concretas: Street, Latitude, Longitude y Geolocation. Demasiado ruido o demasiados registros nulos: Neighbourhood, Host Location, Host Neighbourhood. Por ultimo, Zipcode es una variable que para representar la direccion no me parece la mas adecuada debido a que aunque es un numero, deberia ser tratado como una variable categorica. Ademas contiene bastante ruido, una cantidad no despreciable de nulos y tambien es demasiado concreta (506 valores unicos)     Por tanto y para la evaluacion del modelo deberemos barajar cual de las dos opciones que quedan es la mejor para representar la "zona" en la que se encuentra el piso ( Neighbourhood Cleansed o Neighbourhood Group Cleansed, las cuales obviamente van a estar fuertemente correladas), pero esto debera hacerse una vez separado el dataset, para que los datos de Test no influyan en la decision. (En cualquier caso sera necesario hacer un trabajo de limpieza y categorizacion con la variable elegida):drop_address
# 5. **Informascion relativa al Hospedador**: drop_host

# %%
drop_url = np.array(['Listing Url', 'Thumbnail Url', 'Medium Url', 'Picture Url', 'XL Picture Url', 'Host URL',
                     'Host Thumbnail Url','Host Picture Url'])
full_airbnb.drop(drop_url, axis=1, inplace=True)

drop_id_scrape = np.array(['ID', 'Scrape ID', 'Last Scraped', 'Host ID', 'Calendar last Scraped'])
full_airbnb.drop(drop_id_scrape, axis=1, inplace=True)


drop_comments = np.array(['Name', 'Summary', 'Space', 'Description', 'Neighborhood Overview', 'Notes',
                     'Transit','Access', 'Interaction', 'House Rules', 'Host Name', 'Experiences Offered',
                         'Host About', 'Amenities', 'Features'])

full_airbnb.drop(drop_comments, axis=1, inplace=True)

drop_address = np.array(['Host Location', 'Host Neighbourhood', 'Neighbourhood', 'Street', 'Zipcode', 
    'City', 'State', 'Market', 'Smart Location','Country Code', 'Country', 'Latitude', 
                         'Longitude', 'Jurisdiction Names', 'Geolocation'])

full_airbnb.drop(drop_address, axis=1, inplace=True)

drop_host = np.array(['Host Since', 'Host Response Time', 'Host Response Rate', 'Host Acceptance Rate', 
    'Host Listings Count', 'Host Total Listings Count','Host Verifications', 'Calculated host listings count'])

full_airbnb.drop(drop_host, axis=1, inplace=True)

# %% [markdown]
# Por ultimo eliminamos varios campos sueltos por los siguientes motivos:
# * **Square Feet**: Contiene 96% observaciones null
# * **Weekly Price**: Contiene 76% observaciones null
# * **Monthly Price**: Contiene 76% obsevaciones null
# * **Has Availability**: Contiene 99% observaciones null
# * **First Review**: No creemos que aporte informacion util para el calculo del precio
# * **Last Review**: No creemos que aporte informacion util para el calculo del precio
# * **Calendar Updated**: No creemos que aporte informacion util para el calculo del precio
# * **License**: Contiene 98% observaciones null
# * **Bed Type**: Casi el 99% de las camas son del mismo tipo (Real Bed)

# %%
drop_varios = np.array(['Square Feet', 'Weekly Price', 'Monthly Price', 'Has Availability', 'First Review', 'Last Review',
                     'Calendar Updated','License', 'Bed Type'])

full_airbnb.drop(drop_varios, axis=1, inplace=True)

# %% [markdown]
# **Tras la limpeza inicial nos hemos quedado con 29 caracteristicas (y el target).**

# %% [markdown]
# ## Separación Train Test
#
# Ahora, y antes de pasar al analisis exploratorio y la seleccion de caratresiticas procemos a la divsion del dataset de entrada en train y test. De momento y por si llevamos a cabo tratamiento de outliers no separaremos la variable objetivo del resto de caracteristicas.

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(full_airbnb, test_size=0.2, shuffle=True, random_state=0)
print(f'Dimensiones del dataset de training: {train.shape}')
print(f'Dimensiones del dataset de test: {test.shape}')
# Guardamos
train.to_csv('/content/gdrive/My Drive/Public/Practica_Deep_Learning_DA/data/train.csv', sep=';', decimal='.', index=False)
test.to_csv('/content/gdrive/My Drive/Public/Practica_Deep_Learning_DA/data/test.csv', sep=';', decimal='.', index=False)
# Out:
# Dimensiones del dataset de training: (11248, 29)
# Dimensiones del dataset de test: (2812, 29)

# %% [markdown]
# **Tengamos en cuenta que a partir de ahora todo el analisis exploratorio y selección de caracteristicas se hara sobre el dataset de entrenamiento.**
# **Posteriormente todas transformaciones llevadas a cabo en dicho dataset se deberan implementar en el de Test.**

# %% [markdown]
# ## Limpieza y preprocesado de variables categoticas

# %% [markdown]
# Empecemos tratando las variables de vecindario (Neighbourhood Cleansed y Neighbourhood Group Cleansed)

# %%
print(len(train['Neighbourhood Cleansed'].unique()))
print(train['Neighbourhood Cleansed'].isna().sum())
with pd.option_context("display.max_rows", 1000):
    print(train['Neighbourhood Cleansed'].value_counts())

# %%
print(len(train['Neighbourhood Group Cleansed'].unique()))
print(train['Neighbourhood Group Cleansed'].isna().sum())
with pd.option_context("display.max_rows", 1000):
    print(train['Neighbourhood Group Cleansed'].value_counts())

# %% [markdown]
# A la vista de los datos anteriores tenemos la siguiente informacio:
# - La variable "Neighbourhood Cleansed" contiene 449 categorias y ningun valor null.
# - La variable "Neighbourhood Group Cleansed contiene 49 categorias y 819 celdas null.En lugar de imputar los nulls a la categoria "Other" lo rellenamos con el valor de la columna "Neighbourhood Cleansed"

# %%
train['Neighbourhood Group Cleansed'].fillna(train['Neighbourhood Cleansed'], inplace=True)

# %% [markdown]
# Es cierto que ahora hemos pasado de 49 categorias a 277, pero creemos que esta distribucion es mas realista que la de incluir tantos pisos en la categoria de Other.

# %% [markdown]
# A continuación trataremos las otras tres variables categoricas que nos quedan (Property Type, Room Type y Cancellation Policy)

# %%
print(train['Property Type'].value_counts())
print(train['Room Type'].value_counts())
print(train['Cancellation Policy'].value_counts())
# Out:
# Apartment             9181
# House                  963
# Bed & Breakfast        271
# Condominium            268
# Loft                   246
# Other                  176
# Dorm                    37
# Guesthouse              32
# Chalet                  18
# Hostel                  12
# Townhouse               12
# Serviced apartment       9
# Boutique hotel           5
# Villa                    5
# Boat                     4
# Casa particular          2
# Earth House              2
# Camper/RV                1
# Bungalow                 1
# Timeshare                1
# Guest suite              1
# Tent                     1
# Name: Property Type, dtype: int64
# Entire home/apt    6750
# Private room       4346
# Shared room         152
# Name: Room Type, dtype: int64
# strict             4282
# flexible           3581
# moderate           3302
# strict_new           23
# super_strict_60      18
# moderate_new         17
# super_strict_30      15
# flexible_new         10
# Name: Cancellation Policy, dtype: int64

# %% [markdown]
# Vamos a dejar las categorias de Property Type en "Apartment", "House", "Condominium", "Bed & Breakfast", "Loft", "Dorm", "Guesthouse", "Chalet", "Townhouse", "Hostel" y "Villa" que representan mas del 95% del total y todas las demas las incluiremos en la categoría "Other".
# Para ello usaremos la funcion change_cat_to_other del pakcage utilidades

# %%
array_main_cat_property_type = ['Apartment', 'House', 'Condominium', 'Bed & Breakfast', 'Loft', 'Dorm', 'Guesthouse',
                               'Chalet', 'Townhouse', 'Hostel', 'Villa']
train['Property Type'] = change_cat_to_other(array_main_cat_property_type, train['Property Type'])
train['Property Type'].value_counts()
# Out:
# Apartment          9181
# House               963
# Bed & Breakfast     271
# Condominium         268
# Loft                246
# Other               203
# Dorm                 37
# Guesthouse           32
# Chalet               18
# Hostel               12
# Townhouse            12
# Villa                 5
# Name: Property Type, dtype: int64

# %% [markdown]
# De la misma manera vamos a dejar las categorias de Cancellation Policy en "strict", "flexible" y "moderate", que representan mas del 96% del total y todas las demas las incluiremos en la categoría "Other".
# Usamos nuevamente la funcion change_cat_to_other

# %%
array_main_cat_cancellation_policy = ['strict', 'flexible', 'moderate']
train['Cancellation Policy'] = change_cat_to_other(array_main_cat_cancellation_policy, train['Cancellation Policy'])
train['Cancellation Policy'].value_counts()
# Out:
# strict      4282
# flexible    3581
# moderate    3302
# Other         83
# Name: Cancellation Policy, dtype: int64

# %% [markdown]
# ## Codificacion de las variables categoricas (Mean encoding)
# Una vez reducidas las categorias de las variables categoricas, las convertiremos en numericas mediante el mecanismo de mean
# encoding.
# Guardamos las transformacion hechas en Train para reproducirlas en Test con un replace o un map sin volver a aplicar el mean encoding para evitar que los datos de test infulyan en el modelo.
# Para aplicar le metodo Mean Encoding es conveniente que no haya NaNs en la variable Target (Price), por ello imputaremos esos valores con la media de los precios.

# %%
y_train_mean = np.mean(train['Price'])
train['Price'] = train['Price'].fillna(y_train_mean)

# %%
#Property Type
mean_encode_property_type = train.groupby('Property Type')['Price'].mean()
train.loc[:,'Property Type'] = train['Property Type'].map(mean_encode_property_type)

#Cancellation Policy 
mean_encode_cancellation_policy = train.groupby('Cancellation Policy')['Price'].mean()
train.loc[:,'Cancellation Policy'] = train['Cancellation Policy'].map(mean_encode_cancellation_policy)

#Room Type
mean_encode_room_type = train.groupby('Room Type')['Price'].mean()
train.loc[:,'Room Type'] = train['Room Type'].map(mean_encode_room_type)

#Neighbourhood Cleansed
mean_encode_neigh = train.groupby('Neighbourhood Cleansed')['Price'].mean()
train.loc[:,'Neighbourhood Cleansed'] = train['Neighbourhood Cleansed'].map(mean_encode_neigh)

#Neighbourhood Group Cleansed
mean_encode_neigh_group = train.groupby('Neighbourhood Group Cleansed')['Price'].mean()
train.loc[:,'Neighbourhood Group Cleansed'] = train['Neighbourhood Group Cleansed'].map(mean_encode_neigh_group)

# %% [markdown]
# ## Correlacion de variables

# %%
import seaborn as sns

# Compute the correlation matrix
corr = np.abs(train.drop(['Price'], axis=1).corr())

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask,vmin = 0.0, vmax=1.0, center=0.5,
            linewidths=.1, cmap="YlGnBu", cbar_kws={"shrink": .8})

plt.show()

# %% [markdown]
# A la vista de la grafica de correlacion y siendo un poco generosos con las variables a eliminar para simplificar el modelo, podemos deducir lo siguiente:
# 1. **Accommodates** tiene una fuerte correlacion con Bedrooms, Beds y moderada con Guests Included
# 2. **Availability 30** tiene fuerte correlacion con Availability 60 Availability 90 y moderada con Availability 365
# 3. **Review Scores Rating** tiene una fuerte correlacion con Review Scores Accuracy, Review Scores Cleanliness, Review Scores Checkin, Review Scores Communication, Review Scores Value y moderada con Review Scores Location.
# 4. **Number of Reviews** tiene fuerte  correlacion con Reviews per Month
# 5. **Neighbourhood Cleansed y Neighbourhood Group Cleansed** muestran una fuerte correlacion, pero de momento dejamos las dos para analizar mediante el filtrado de caracterisdtcas cual de las dos influye mas en la regresion que tenemos que plantear.

# %%
#Vamos a eliminar todas estas variables del dataset de entrenamiento
drop_corr = ['Bedrooms', 'Beds', 'Guests Included', 'Availability 60', 'Availability 90', 'Availability 365',
             'Review Scores Accuracy', 'Review Scores Cleanliness', 'Review Scores Checkin', 'Review Scores Communication',
             'Review Scores Value', 'Review Scores Location', 'Reviews per Month']
train.drop(drop_corr, axis=1, inplace=True)
train.shape
# Out:
# (11248, 16)

# %% [markdown]
# ## Tratamiento de NaNs (Imputacion de nulos)

# %% [markdown]
# Ningun modelo de Machine o Deep Learning funcionan adecuadamente sin un tratamiento previo de los NaNs de sus registros.
#
# Por tanto debemos analizar que variables tienen valores NaN y llevemos a cabo el proceso de imputacion
#
# Para hacerlo una opcion seria aplicar los siguientes comandos a todas las variables que quedan:
# ```
# print(len(train['campo'].unique()))
# print(train['campo'].isna().sum())
# print(train['campo'].value_counts())
#
# ```
#
# Afortunadamente contamos con la funion missing_values_table que nos permite visualizar con un unico comando los nulos que aparecen en los distintos campos del dataframe

# %%
missing_values_table(train)
# Out:
# Your slelected dataframe has 16 columns.
# There are 4 columns that have missing values.
#                       Missing Values  % of Total Values
# Security Deposit                6432              57.18
# Cleaning Fee                    4586              40.77
# Review Scores Rating            2376              21.12
# Bathrooms                         41               0.36

# %% [markdown]
# Haciendo esto vemos que los unicos campos que contienen NaNs son:
# - Bathroom (45) Imputamos la media
# - Security Deposit (6798). Es mas de la mitad de los regitros por lo que lo eliminamos
# - Cleaning Fee (4857). Imputamnos un cero. asumismos que quien no tiene ese dato es porque no hay gastos de limpieza.
# - Review Scores Rating (2651). Imputamos la media. **En su momento consideramos que el no tener este campo relleno no era buena señal por que probamos a imputar el minimo, en lugar de la media, pero el modelo predecia peor, por lo que desestimamos nuestra hipotesis y volvimos a la media**.

# %%
mean_bathroom = np.mean(train['Bathrooms'])
mean_review = np.mean(train['Review Scores Rating'])
min_review = np.min(train['Review Scores Rating'])
train['Bathrooms'] = train['Bathrooms'].fillna(mean_bathroom)
train['Cleaning Fee'] = train['Cleaning Fee'].fillna(0)
train['Review Scores Rating'] = train['Review Scores Rating'].fillna(mean_review)

# %%
train.drop('Security Deposit', axis=1, inplace=True)

# %% [markdown]
# ## Separacion y tratamiento de la variable dependiente (variable objetivo o target)
# Separemos el dataset train entre la varible dependiente (y_train) y el resto de variables independientes (X_train)

# %%
y_train = train['Price']
X_train= train.drop(['Price'], axis=1)

# %%
X_train.shape
# Out:
# (11248, 14)

# %%
y_train.describe()
# Out:
# count    11248.000000
# mean        62.438122
# std         37.958864
# min         11.000000
# 25%         32.000000
# 50%         55.000000
# 75%         80.000000
# max        199.000000
# Name: Price, dtype: float64

# %%
print(len(y_train.unique()))
print(y_train.isna().sum())
print(y_train.value_counts())
print(np.mean(y_train))
# Out:
# 183
# 0
# 50.0     516
# 60.0     455
# 25.0     442
# 30.0     440
# 35.0     372
#         ...
# 184.0      1
# 173.0      1
# 174.0      1
# 193.0      1
# 171.0      1
# Name: Price, Length: 183, dtype: int64
# 62.43812233285917

# %% [markdown]
# ## Filtrado para regresion
# Con las 14 variables que me quedan aplico los metodos de fitrado **f_regresion** y **mutual_info_regresion**

# %%
from sklearn.feature_selection import f_regression, mutual_info_regression
f_test, _ = f_regression(X_train, y_train)
f_test /= np.max(f_test)
mi = mutual_info_regression(X_train, y_train)
mi /= np.max(mi)

# %% [markdown]
# Mostremos esta informacion en forma de grafica

# %%
featureNames = list(X_train.columns)

plt.figure(figsize=(30, 10))

plt.subplot(1,2,1)
plt.bar(range(X_train.shape[1]),f_test,  align="center")
plt.xticks(range(X_train.shape[1]),featureNames, rotation = 90)
plt.xlabel('features')
plt.ylabel('Ranking')
plt.title('$F-test$ score')


plt.subplot(1,2,2)
plt.bar(range(X_train.shape[1]),mi,  align="center")
plt.xticks(range(X_train.shape[1]),featureNames, rotation = 90)
plt.xlabel('features')
plt.ylabel('Ranking')
plt.title('Mutual information score')

plt.show()

# %% [markdown]
# A la vista de las graficas y de los valores de f_test y mi las variables que mas estan impactando en la variable objetivo son:
# - Neighbourhood Cleansed (quitamos la grupal pues como ya habiamos visto esta fuertemente correlada con esta)
# - Room Type
# - Accommodates
# - Bathrooms
# - Cleaning Fee
# - Extra People
# - Minimum Nigths
# - Availability 30
# - cancelation Policy
# - Review Scores Rating
#
# Como era de esperar el barrio, el tipo de habitacion y las personas que pueden ocupar la casa son los parametros que mas afectan al precio de la casa.
#
# Por tanto seran estas las variables que usare para testear mis modelos, elimando el resto del dataset de training

# %%
drop_filtrado = ['Neighbourhood Group Cleansed', 'Property Type','Maximum Nights', 'Number of Reviews']
X_train.drop(drop_filtrado, axis=1, inplace=True)

# %% [markdown]
# Por ultimo cambiare el nombre de la variable "Neighbourhood Group Cleansed" por "Barrio" para que sea mas manejable

# %%
X_train.rename(columns={'Neighbourhood Cleansed':'Barrio'}, inplace=True)

# %%
X_train.describe()
# Out:
#              Barrio     Room Type  ...  Review Scores Rating  Cancellation Policy
# count  11248.000000  11248.000000  ...          11248.000000         11248.000000
# mean      62.438122     62.438122  ...             91.649121            62.438122
# std       18.576971     23.404771  ...              7.930730             7.343593
# min       17.500000     28.388158  ...             20.000000            53.291818
# 25%       51.193237     33.967326  ...             90.000000            53.291818
# 50%       63.712644     81.535852  ...             91.649121            61.493943
# 75%       69.968485     81.535852  ...             97.000000            70.453293
# max      198.000000     81.535852  ...            100.000000            81.108434
#
# [8 rows x 10 columns]

# %% [markdown]
# ## Normalizacion
# Por ultimo llevamos a cabo la normalizacion. Usaremos varias opciones para ver cual es la que mejor se adapta a nuestro modelo:
# *   StandarEscaler
# *   MinMax
#
#
# Recordemos que para test deberemos usar el scaler obtenido en train

# %%
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler

#StandardScaler
standardScalerX = preprocessing.StandardScaler().fit(X_train)
XtrainStdScaled = standardScalerX.transform(X_train)

standardScalerY = preprocessing.StandardScaler().fit(np.array(y_train).reshape(-1, 1))
YtrainStdScaled = standardScalerY.transform(np.array(y_train).reshape(-1, 1))

#MinMax
cs = MinMaxScaler()
XtrainMmScaled = cs.fit_transform(X_train)

maxPrice = train["Price"].max()
YtrainMmScaled = np.array(y_train).reshape(-1, 1)/maxPrice

# %% [markdown]
# **Y hasta aqui el analisis exploratorio y la limpieza del dataset, empezamos con las pruebas de los modelos**

# %% [markdown]
# ## Preparacion datos Test

# %% [markdown]
# Antes de iniciar la evaluacion de modelos, vamos a dejar preparado el **dataset de Test** con las mismas transformaciones que hemos llevado a cabo sobre el de Train.
# Abajo indicamos el listado de dichas transformaciones para no olvidarnos de ninguna:
# - Lo primero es el dropeo de las variables que no van a participar en el modelo (correlacion y filtrado): drop_corr y drop_filtrado.
# - Drop de "Security Deposit"
# - Tratamiento de las variables categoricas que influyen en el modelo (filtrado de categorias y Encoder): mean_encode_room_type, mean_encode_neigh y mean_encode_cancellation_policy
# - Imputacion  de NaNs: Price, Bathroom y Cleaning Fee

# %% [markdown]
# ### Analizamos y limpiamos el dataset de test

# %%
test = pd.read_csv('/content/gdrive/My Drive/Public/Practica_Deep_Learning_DA/data/test.csv',sep=';', decimal='.')
test.shape
#test.info()
# Out:
# (2812, 29)

# %%
missing_values_table(test)
# Out:
# Your slelected dataframe has 29 columns.
# There are 14 columns that have missing values.
#                               Missing Values  % of Total Values
# Security Deposit                        1659              59.00
# Cleaning Fee                            1169              41.57
# Review Scores Location                   629              22.37
# Review Scores Value                      629              22.37
# Review Scores Checkin                    628              22.33
# Review Scores Accuracy                   625              22.23
# Review Scores Cleanliness                624              22.19
# Review Scores Communication              623              22.16
# Review Scores Rating                     618              21.98
# Reviews per Month                        589              20.95
# Neighbourhood Group Cleansed             167               5.94
# Beds                                      11               0.39
# Bathrooms                                 10               0.36
# Bedrooms                                   7               0.25

# %%
#Dropeamos
test.drop(drop_corr, axis=1, inplace=True)
test.drop(drop_filtrado, axis=1, inplace=True)

#Eliminamos tambien la variable Security Deposit 
test.drop('Security Deposit', axis=1, inplace=True)

#imputamos los valores NaNs del target con la media del train (y_train_mean)
media_target_test = np.mean(test['Price'])
test['Price'] = test['Price'].fillna(y_train_mean)

#Imputamos los NaNs de la misma manera que se hace en Train
test['Bathrooms'] = test['Bathrooms'].fillna(mean_bathroom)
test['Cleaning Fee'] = test['Cleaning Fee'].fillna(0)
test['Review Scores Rating'] = test['Review Scores Rating'].fillna(mean_review)


#Aplicamos el Mean Encoder a "Room Type", "Neighbourhood Cleansed" y "Cancellation Policy"  el obtenido en train, si aparece alguna categoria nueva en test
#lo trataremos a posteriori
#mean_encode_room_type_test = test.groupby('Room Type')['Price'].mean()
#mean_encode_neigh_test = test.groupby('Neighbourhood Cleansed')['Price'].mean()
#mean_encode_cancellation_policy_test = test.groupby('Cancellation Policy')['Price'].mean()
test.loc[:,'Room Type'] = test['Room Type'].map(mean_encode_room_type)
test.loc[:,'Neighbourhood Cleansed'] = test['Neighbourhood Cleansed'].map(mean_encode_neigh)
test.loc[:,'Cancellation Policy'] = test['Cancellation Policy'].map(mean_encode_cancellation_policy)


#Por ultimo cambiamos el nombre de la variable a Barrio
test.rename(columns={'Neighbourhood Cleansed':'Barrio'}, inplace=True)

# %%
missing_values_table(test)
# Out:
# Your slelected dataframe has 11 columns.
# There are 2 columns that have missing values.
#                      Missing Values  % of Total Values
# Barrio                           26               0.92
# Cancellation Policy              22               0.78

# %% [markdown]
# Como quedan valores nulos en Barrio y Cancellation Policy debido a aplicar sobre ellas el Mean Encoding de train, lo rellenaremos con la media de las medias obtenidas para esas categoria

# %%
mean_mean_encode_neigh = np.mean(mean_encode_neigh)
mean_mean_encode_cancellation_policy = np.mean(mean_encode_cancellation_policy)
test['Barrio'].fillna(mean_mean_encode_neigh, inplace=True)
test['Cancellation Policy'].fillna(mean_mean_encode_cancellation_policy, inplace=True)

# %% [markdown]
# ### Separamos la variable objetivo del tets

# %%
y_test = test['Price']
X_test= test.drop(['Price'], axis=1)

# %% [markdown]
# Normalizamos los datos de Test usando las normalizaciones de Train

# %%
#StandardScaler
XtestStdScaled = standardScalerX.transform(X_test)
YtestStdScaled = standardScalerY.transform(np.array(y_test).reshape(-1, 1))

#MinMax
cs = MinMaxScaler()
XtestMmScaled = cs.fit_transform(X_test)

YtestMmScaled = np.array(y_test).reshape(-1, 1)/maxPrice

# %% [markdown]
# # Red Neuronal
# Creamos nuestra primera RN para una prueba de regresion
# Para este ejemplo  usaremos una arquitectura sencilla de tipo Multilayer Perceptron (MLP)

# %% [markdown]
# ## Imports

# %%
# Llevamos a cabo los import necesarios

from keras.models import Sequential
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ## Definicion del modelo de Red Neuronal

# %%
# Inicializamos el modelo
model = Sequential()

#Añadimos las capas neuronales tradicionales (Densas)
#Obtenemos mejores resultados (poco mejores la verdad) con selu que con relu, asi que optamos por la primera.
model.add(Dense(64,activation='selu', input_shape=(10,)))
model.add(Dense(32,activation='selu'))
model.add(Dense(8,activation='selu'))
model.add(Dense(1, activation="linear"))

#Ponemos el numero de epocas como una variable:
# veamos nuestra curva de pérdidas
#No vale la pena meterle mas de 100 eporcas porque converge pronto...
n_epochs = 100


# Compilamos el modelo
model.compile(loss='mean_absolute_error',
              optimizer=Adam(lr=0.01, decay=1e-3),
              metrics=['mae'])

# %% [markdown]
# ## Probamos con los datos Normalizados

# %% [markdown]
# ### Entrenamiento

# %%
# Entrenamos el modelo
history_callback  = model.fit(XtrainStdScaled, YtrainMmScaled,
          batch_size=64,
          shuffle=True,
          epochs=n_epochs,
          validation_data=(XtestStdScaled, YtestMmScaled))

# Evaluamos el modelo
scores = model.evaluate(XtestStdScaled, YtestMmScaled)

print('Test Loss: %.3f' % scores[0])
print('Test MAE: %.3f' % scores[1])
# Out:
# Train on 11248 samples, validate on 2812 samples
# Epoch 1/100
# 11248/11248 [==============================] - 1s 77us/step - loss: 0.1627 - mean_absolute_error: 0.1627 - val_loss: 0.0929 - val_mean_absolute_error: 0.0929
# Epoch 2/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0874 - mean_absolute_error: 0.0874 - val_loss: 0.0825 - val_mean_absolute_error: 0.0825
# Epoch 3/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 0.0833 - mean_absolute_error: 0.0833 - val_loss: 0.0821 - val_mean_absolute_error: 0.0821
# Epoch 4/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 0.0794 - mean_absolute_error: 0.0794 - val_loss: 0.0753 - val_mean_absolute_error: 0.0753
# Epoch 5/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0783 - mean_absolute_error: 0.0783 - val_loss: 0.0776 - val_mean_absolute_error: 0.0776
# Epoch 6/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0784 - mean_absolute_error: 0.0784 - val_loss: 0.0727 - val_mean_absolute_error: 0.0727
# Epoch 7/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 0.0753 - mean_absolute_error: 0.0753 - val_loss: 0.0726 - val_mean_absolute_error: 0.0726
# Epoch 8/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0754 - mean_absolute_error: 0.0754 - val_loss: 0.0746 - val_mean_absolute_error: 0.0746
# Epoch 9/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0745 - mean_absolute_error: 0.0745 - val_loss: 0.0736 - val_mean_absolute_error: 0.0736
# Epoch 10/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0750 - mean_absolute_error: 0.0750 - val_loss: 0.0742 - val_mean_absolute_error: 0.0742
# Epoch 11/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0740 - mean_absolute_error: 0.0740 - val_loss: 0.0708 - val_mean_absolute_error: 0.0708
# Epoch 12/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0735 - mean_absolute_error: 0.0735 - val_loss: 0.0728 - val_mean_absolute_error: 0.0728
# Epoch 13/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0742 - mean_absolute_error: 0.0742 - val_loss: 0.0734 - val_mean_absolute_error: 0.0734
# Epoch 14/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0736 - mean_absolute_error: 0.0736 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710
# Epoch 15/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0731 - mean_absolute_error: 0.0731 - val_loss: 0.0717 - val_mean_absolute_error: 0.0717
# Epoch 16/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0732 - mean_absolute_error: 0.0732 - val_loss: 0.0707 - val_mean_absolute_error: 0.0707
# Epoch 17/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0730 - mean_absolute_error: 0.0730 - val_loss: 0.0736 - val_mean_absolute_error: 0.0736
# Epoch 18/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0731 - mean_absolute_error: 0.0731 - val_loss: 0.0727 - val_mean_absolute_error: 0.0727
# Epoch 19/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0729 - mean_absolute_error: 0.0729 - val_loss: 0.0738 - val_mean_absolute_error: 0.0738
# Epoch 20/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0726 - mean_absolute_error: 0.0726 - val_loss: 0.0719 - val_mean_absolute_error: 0.0719
# Epoch 21/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0727 - mean_absolute_error: 0.0727 - val_loss: 0.0707 - val_mean_absolute_error: 0.0707
# Epoch 22/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 0.0721 - mean_absolute_error: 0.0721 - val_loss: 0.0705 - val_mean_absolute_error: 0.0705
# Epoch 23/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0720 - mean_absolute_error: 0.0720 - val_loss: 0.0708 - val_mean_absolute_error: 0.0708
# Epoch 24/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0720 - mean_absolute_error: 0.0720 - val_loss: 0.0713 - val_mean_absolute_error: 0.0713
# Epoch 25/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 0.0715 - mean_absolute_error: 0.0715 - val_loss: 0.0709 - val_mean_absolute_error: 0.0709
# Epoch 26/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 0.0715 - mean_absolute_error: 0.0715 - val_loss: 0.0707 - val_mean_absolute_error: 0.0707
# Epoch 27/100
# 11248/11248 [==============================] - 0s 30us/step - loss: 0.0716 - mean_absolute_error: 0.0716 - val_loss: 0.0725 - val_mean_absolute_error: 0.0725
# Epoch 28/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0718 - mean_absolute_error: 0.0718 - val_loss: 0.0712 - val_mean_absolute_error: 0.0712
# Epoch 29/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0713 - mean_absolute_error: 0.0713 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710
# Epoch 30/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0711 - mean_absolute_error: 0.0711 - val_loss: 0.0718 - val_mean_absolute_error: 0.0718
# Epoch 31/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0713 - mean_absolute_error: 0.0713 - val_loss: 0.0703 - val_mean_absolute_error: 0.0703
# Epoch 32/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0711 - mean_absolute_error: 0.0711 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710
# Epoch 33/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 0.0713 - mean_absolute_error: 0.0713 - val_loss: 0.0728 - val_mean_absolute_error: 0.0728
# Epoch 34/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 0.0708 - mean_absolute_error: 0.0708 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 35/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 0.0708 - mean_absolute_error: 0.0708 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700
# Epoch 36/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0704 - mean_absolute_error: 0.0704 - val_loss: 0.0715 - val_mean_absolute_error: 0.0715
# Epoch 37/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0706 - mean_absolute_error: 0.0706 - val_loss: 0.0727 - val_mean_absolute_error: 0.0727
# Epoch 38/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0705 - mean_absolute_error: 0.0705 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710
# Epoch 39/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0702 - mean_absolute_error: 0.0702 - val_loss: 0.0707 - val_mean_absolute_error: 0.0707
# Epoch 40/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0703 - mean_absolute_error: 0.0703 - val_loss: 0.0708 - val_mean_absolute_error: 0.0708
# Epoch 41/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0705 - mean_absolute_error: 0.0705 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704
# Epoch 42/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0700 - mean_absolute_error: 0.0700 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710
# Epoch 43/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0702 - mean_absolute_error: 0.0702 - val_loss: 0.0715 - val_mean_absolute_error: 0.0715
# Epoch 44/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0699 - mean_absolute_error: 0.0699 - val_loss: 0.0716 - val_mean_absolute_error: 0.0716
# Epoch 45/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0697 - mean_absolute_error: 0.0697 - val_loss: 0.0702 - val_mean_absolute_error: 0.0702
# Epoch 46/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0699 - mean_absolute_error: 0.0699 - val_loss: 0.0717 - val_mean_absolute_error: 0.0717
# Epoch 47/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0698 - mean_absolute_error: 0.0698 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704
# Epoch 48/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0698 - mean_absolute_error: 0.0698 - val_loss: 0.0714 - val_mean_absolute_error: 0.0714
# Epoch 49/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0699 - mean_absolute_error: 0.0699 - val_loss: 0.0736 - val_mean_absolute_error: 0.0736
# Epoch 50/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0696 - mean_absolute_error: 0.0696 - val_loss: 0.0707 - val_mean_absolute_error: 0.0707
# Epoch 51/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0692 - mean_absolute_error: 0.0692 - val_loss: 0.0701 - val_mean_absolute_error: 0.0701
# Epoch 52/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0696 - mean_absolute_error: 0.0696 - val_loss: 0.0702 - val_mean_absolute_error: 0.0702
# Epoch 53/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0694 - mean_absolute_error: 0.0694 - val_loss: 0.0725 - val_mean_absolute_error: 0.0725
# Epoch 54/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0691 - mean_absolute_error: 0.0691 - val_loss: 0.0709 - val_mean_absolute_error: 0.0709
# Epoch 55/100
# 11248/11248 [==============================] - 0s 30us/step - loss: 0.0692 - mean_absolute_error: 0.0692 - val_loss: 0.0719 - val_mean_absolute_error: 0.0719
# Epoch 56/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0693 - mean_absolute_error: 0.0693 - val_loss: 0.0702 - val_mean_absolute_error: 0.0702
# Epoch 57/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0691 - mean_absolute_error: 0.0691 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710
# Epoch 58/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0690 - mean_absolute_error: 0.0690 - val_loss: 0.0703 - val_mean_absolute_error: 0.0703
# Epoch 59/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0687 - mean_absolute_error: 0.0687 - val_loss: 0.0706 - val_mean_absolute_error: 0.0706
# Epoch 60/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0689 - mean_absolute_error: 0.0689 - val_loss: 0.0714 - val_mean_absolute_error: 0.0714
# Epoch 61/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0689 - mean_absolute_error: 0.0689 - val_loss: 0.0701 - val_mean_absolute_error: 0.0701
# Epoch 62/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0688 - mean_absolute_error: 0.0688 - val_loss: 0.0697 - val_mean_absolute_error: 0.0697
# Epoch 63/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0689 - mean_absolute_error: 0.0689 - val_loss: 0.0702 - val_mean_absolute_error: 0.0702
# Epoch 64/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0684 - mean_absolute_error: 0.0684 - val_loss: 0.0702 - val_mean_absolute_error: 0.0702
# Epoch 65/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0686 - mean_absolute_error: 0.0686 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700
# Epoch 66/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0686 - mean_absolute_error: 0.0686 - val_loss: 0.0697 - val_mean_absolute_error: 0.0697
# Epoch 67/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0686 - mean_absolute_error: 0.0686 - val_loss: 0.0699 - val_mean_absolute_error: 0.0699
# Epoch 68/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0682 - mean_absolute_error: 0.0682 - val_loss: 0.0702 - val_mean_absolute_error: 0.0702
# Epoch 69/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0684 - mean_absolute_error: 0.0684 - val_loss: 0.0706 - val_mean_absolute_error: 0.0706
# Epoch 70/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0682 - mean_absolute_error: 0.0682 - val_loss: 0.0706 - val_mean_absolute_error: 0.0706
# Epoch 71/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0682 - mean_absolute_error: 0.0682 - val_loss: 0.0726 - val_mean_absolute_error: 0.0726
# Epoch 72/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0682 - mean_absolute_error: 0.0682 - val_loss: 0.0698 - val_mean_absolute_error: 0.0698
# Epoch 73/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0682 - mean_absolute_error: 0.0682 - val_loss: 0.0703 - val_mean_absolute_error: 0.0703
# Epoch 74/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0679 - mean_absolute_error: 0.0679 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 75/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0680 - mean_absolute_error: 0.0680 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704
# Epoch 76/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0681 - mean_absolute_error: 0.0681 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704
# Epoch 77/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0681 - mean_absolute_error: 0.0681 - val_loss: 0.0697 - val_mean_absolute_error: 0.0697
# Epoch 78/100
# 11248/11248 [==============================] - 0s 30us/step - loss: 0.0680 - mean_absolute_error: 0.0680 - val_loss: 0.0698 - val_mean_absolute_error: 0.0698
# Epoch 79/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0681 - mean_absolute_error: 0.0681 - val_loss: 0.0694 - val_mean_absolute_error: 0.0694
# Epoch 80/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0679 - mean_absolute_error: 0.0679 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 81/100
# 11248/11248 [==============================] - 0s 30us/step - loss: 0.0679 - mean_absolute_error: 0.0679 - val_loss: 0.0695 - val_mean_absolute_error: 0.0695
# Epoch 82/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0678 - mean_absolute_error: 0.0678 - val_loss: 0.0702 - val_mean_absolute_error: 0.0702
# Epoch 83/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0676 - mean_absolute_error: 0.0676 - val_loss: 0.0718 - val_mean_absolute_error: 0.0718
# Epoch 84/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0674 - mean_absolute_error: 0.0674 - val_loss: 0.0695 - val_mean_absolute_error: 0.0695
# Epoch 85/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0675 - mean_absolute_error: 0.0675 - val_loss: 0.0699 - val_mean_absolute_error: 0.0699
# Epoch 86/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0677 - mean_absolute_error: 0.0677 - val_loss: 0.0698 - val_mean_absolute_error: 0.0698
# Epoch 87/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0676 - mean_absolute_error: 0.0676 - val_loss: 0.0701 - val_mean_absolute_error: 0.0701
# Epoch 88/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0674 - mean_absolute_error: 0.0674 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 89/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0673 - mean_absolute_error: 0.0673 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696
# Epoch 90/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 0.0675 - mean_absolute_error: 0.0675 - val_loss: 0.0708 - val_mean_absolute_error: 0.0708
# Epoch 91/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 0.0674 - mean_absolute_error: 0.0674 - val_loss: 0.0697 - val_mean_absolute_error: 0.0697
# Epoch 92/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0673 - mean_absolute_error: 0.0673 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710
# Epoch 93/100
# 11248/11248 [==============================] - 0s 30us/step - loss: 0.0677 - mean_absolute_error: 0.0677 - val_loss: 0.0697 - val_mean_absolute_error: 0.0697
# Epoch 94/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0671 - mean_absolute_error: 0.0671 - val_loss: 0.0699 - val_mean_absolute_error: 0.0699
# Epoch 95/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0672 - mean_absolute_error: 0.0672 - val_loss: 0.0691 - val_mean_absolute_error: 0.0691
# Epoch 96/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0672 - mean_absolute_error: 0.0672 - val_loss: 0.0694 - val_mean_absolute_error: 0.0694
# Epoch 97/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0672 - mean_absolute_error: 0.0672 - val_loss: 0.0699 - val_mean_absolute_error: 0.0699
# Epoch 98/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 0.0672 - mean_absolute_error: 0.0672 - val_loss: 0.0698 - val_mean_absolute_error: 0.0698
# Epoch 99/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 0.0671 - mean_absolute_error: 0.0671 - val_loss: 0.0692 - val_mean_absolute_error: 0.0692
# Epoch 100/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 0.0670 - mean_absolute_error: 0.0670 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700
# 2812/2812 [==============================] - 0s 24us/step
# Test Loss: 0.070
# Test MAE: 0.070

# %% [markdown]
# ### Curva de perdidas

# %%
# veamos nuestra curva de pérdidas
plt.plot(np.arange(0, n_epochs), history_callback.history["loss"])
plt.title("Training Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# A la vista de estos datos observamos que el modelo converge rapidamente y a partir de la epoca 60 ya practicamente no mejora.

# %% [markdown]
# ### Bondad del modelo.
#  **Si bien el error cuadratico medio nos da una estimacion "relativa" de lo bien o mal que se comporta nuestro modelo frente a otros necesitamos un estimador diferente para hacernos una idea real de la bondad del modelo propuesto.**
#
# **No es lo mismo tener un mse de 300 cuando estamos prediciendo el precio de "cosas" que tienen un valor medio de 1.000 € que si obtenemos ese mismo mse para "cosas" con un precio medio de 100 €**

# %%
# Obtenemos la prediccion de nuestro modelo para los datos de Test
preds = model.predict(XtestStdScaled)
 

# Calulamos la diferencia entre los precios predichos y los reales
# A continuacion calcularemos la diferencia porcentual y la diferecia absouta en porcentaje
diff = preds.flatten() - YtestMmScaled
percentDiff = (diff / YtestMmScaled) * 100
absPercentDiff = np.abs(percentDiff)
 

#Calculamos la media y la desviacion estandar
mean = np.mean(absPercentDiff)
std = np.std(absPercentDiff)
 
# Mostramos las estadisticas de nuestro modelo.
print("Precio medio de las pisos: {:.2f}€, Desviacion standar: {:.2f}€".format(
    full_airbnb["Price"].mean(), full_airbnb["Price"].std()))
print("Modelo --> mean: {:.2f}%, std: {:.2f}%".format(mean, std))
# Out:
# Precio medio de las pisos: 62.07€, Desviacion standar: 37.64€
# Modelo --> mean: 83.73%, std: 105.87%

# %% [markdown]
# ## Probamos ahora sin Normalizar
#
# **¡¡¡¡¡IMPORTANTE!!!! Debemos volver a ejecutar la celda en la que se crea la Red Neuronal para resetearla antes de volver a entrenarla con los datos sin normalizar**
#
# **No he sido capaz de entensder porque obtengo mejores resultados (mejor bondad del modelo) con los datos sin normalizar que normalizados.**

# %% [markdown]
# ### Entrenamiento

# %%
# Entrenamos el modelo
history_callback  = model.fit(X_train, y_train,
          batch_size=64,
          shuffle=True,
          epochs=n_epochs,
          validation_data=(X_test, y_test))

# Evaluamos el modelo
scores = model.evaluate(X_test, y_test)

print('Test Loss: %.3f' % scores[0])
print('Test MSE: %.3f' % scores[1])
# Out:
# Train on 11248 samples, validate on 2812 samples
# Epoch 1/100
# 11248/11248 [==============================] - 1s 67us/step - loss: 18.1455 - mean_absolute_error: 18.1455 - val_loss: 16.8078 - val_mean_absolute_error: 16.8078
# Epoch 2/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 16.7401 - mean_absolute_error: 16.7401 - val_loss: 16.1794 - val_mean_absolute_error: 16.1794
# Epoch 3/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 16.0868 - mean_absolute_error: 16.0868 - val_loss: 15.5543 - val_mean_absolute_error: 15.5543
# Epoch 4/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 16.0361 - mean_absolute_error: 16.0361 - val_loss: 15.2980 - val_mean_absolute_error: 15.2980
# Epoch 5/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 15.5327 - mean_absolute_error: 15.5327 - val_loss: 16.5048 - val_mean_absolute_error: 16.5048
# Epoch 6/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 15.5342 - mean_absolute_error: 15.5342 - val_loss: 15.0904 - val_mean_absolute_error: 15.0904
# Epoch 7/100
# 11248/11248 [==============================] - 0s 25us/step - loss: 15.2795 - mean_absolute_error: 15.2795 - val_loss: 15.1602 - val_mean_absolute_error: 15.1602
# Epoch 8/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 15.3160 - mean_absolute_error: 15.3160 - val_loss: 14.4877 - val_mean_absolute_error: 14.4877
# Epoch 9/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 15.0724 - mean_absolute_error: 15.0724 - val_loss: 14.8929 - val_mean_absolute_error: 14.8929
# Epoch 10/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 14.7197 - mean_absolute_error: 14.7197 - val_loss: 15.0361 - val_mean_absolute_error: 15.0361
# Epoch 11/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 14.6679 - mean_absolute_error: 14.6679 - val_loss: 14.4705 - val_mean_absolute_error: 14.4705
# Epoch 12/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 14.5780 - mean_absolute_error: 14.5780 - val_loss: 14.2771 - val_mean_absolute_error: 14.2771
# Epoch 13/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 14.5050 - mean_absolute_error: 14.5050 - val_loss: 14.1762 - val_mean_absolute_error: 14.1762
# Epoch 14/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 14.4485 - mean_absolute_error: 14.4485 - val_loss: 14.1280 - val_mean_absolute_error: 14.1280
# Epoch 15/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 14.5425 - mean_absolute_error: 14.5425 - val_loss: 14.2100 - val_mean_absolute_error: 14.2100
# Epoch 16/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 14.3894 - mean_absolute_error: 14.3894 - val_loss: 14.1867 - val_mean_absolute_error: 14.1867
# Epoch 17/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 14.3506 - mean_absolute_error: 14.3506 - val_loss: 14.0616 - val_mean_absolute_error: 14.0616
# Epoch 18/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 14.2821 - mean_absolute_error: 14.2821 - val_loss: 14.2919 - val_mean_absolute_error: 14.2919
# Epoch 19/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 14.2298 - mean_absolute_error: 14.2298 - val_loss: 14.7603 - val_mean_absolute_error: 14.7603
# Epoch 20/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 14.1867 - mean_absolute_error: 14.1867 - val_loss: 14.2217 - val_mean_absolute_error: 14.2217
# Epoch 21/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 14.1261 - mean_absolute_error: 14.1261 - val_loss: 13.9712 - val_mean_absolute_error: 13.9712
# Epoch 22/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 14.1001 - mean_absolute_error: 14.1001 - val_loss: 13.9415 - val_mean_absolute_error: 13.9415
# Epoch 23/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 14.0706 - mean_absolute_error: 14.0706 - val_loss: 14.4047 - val_mean_absolute_error: 14.4047
# Epoch 24/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 14.0469 - mean_absolute_error: 14.0469 - val_loss: 14.0970 - val_mean_absolute_error: 14.0970
# Epoch 25/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 14.0254 - mean_absolute_error: 14.0254 - val_loss: 13.8673 - val_mean_absolute_error: 13.8673
# Epoch 26/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 14.0043 - mean_absolute_error: 14.0043 - val_loss: 13.9198 - val_mean_absolute_error: 13.9198
# Epoch 27/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 14.0353 - mean_absolute_error: 14.0353 - val_loss: 14.3300 - val_mean_absolute_error: 14.3300
# Epoch 28/100
# 11248/11248 [==============================] - 0s 25us/step - loss: 13.9370 - mean_absolute_error: 13.9370 - val_loss: 13.8391 - val_mean_absolute_error: 13.8391
# Epoch 29/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.8736 - mean_absolute_error: 13.8736 - val_loss: 13.8196 - val_mean_absolute_error: 13.8196
# Epoch 30/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 13.8921 - mean_absolute_error: 13.8921 - val_loss: 13.9443 - val_mean_absolute_error: 13.9443
# Epoch 31/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 13.8782 - mean_absolute_error: 13.8782 - val_loss: 13.9369 - val_mean_absolute_error: 13.9369
# Epoch 32/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.8519 - mean_absolute_error: 13.8519 - val_loss: 13.7742 - val_mean_absolute_error: 13.7742
# Epoch 33/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.8623 - mean_absolute_error: 13.8623 - val_loss: 13.9339 - val_mean_absolute_error: 13.9339
# Epoch 34/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.8700 - mean_absolute_error: 13.8700 - val_loss: 13.8284 - val_mean_absolute_error: 13.8284
# Epoch 35/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.8016 - mean_absolute_error: 13.8016 - val_loss: 13.8556 - val_mean_absolute_error: 13.8556
# Epoch 36/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 13.7617 - mean_absolute_error: 13.7617 - val_loss: 13.7697 - val_mean_absolute_error: 13.7697
# Epoch 37/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.8260 - mean_absolute_error: 13.8260 - val_loss: 13.8068 - val_mean_absolute_error: 13.8068
# Epoch 38/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.7667 - mean_absolute_error: 13.7667 - val_loss: 13.7583 - val_mean_absolute_error: 13.7583
# Epoch 39/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 13.7386 - mean_absolute_error: 13.7386 - val_loss: 13.8933 - val_mean_absolute_error: 13.8933
# Epoch 40/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.7073 - mean_absolute_error: 13.7073 - val_loss: 13.8199 - val_mean_absolute_error: 13.8199
# Epoch 41/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.7180 - mean_absolute_error: 13.7180 - val_loss: 13.8465 - val_mean_absolute_error: 13.8465
# Epoch 42/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.6752 - mean_absolute_error: 13.6752 - val_loss: 13.6792 - val_mean_absolute_error: 13.6792
# Epoch 43/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.7475 - mean_absolute_error: 13.7475 - val_loss: 13.7915 - val_mean_absolute_error: 13.7915
# Epoch 44/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.6535 - mean_absolute_error: 13.6535 - val_loss: 13.6502 - val_mean_absolute_error: 13.6502
# Epoch 45/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.6318 - mean_absolute_error: 13.6318 - val_loss: 13.8608 - val_mean_absolute_error: 13.8608
# Epoch 46/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.6519 - mean_absolute_error: 13.6519 - val_loss: 14.7803 - val_mean_absolute_error: 14.7803
# Epoch 47/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.6426 - mean_absolute_error: 13.6426 - val_loss: 13.7174 - val_mean_absolute_error: 13.7174
# Epoch 48/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.5995 - mean_absolute_error: 13.5995 - val_loss: 13.8154 - val_mean_absolute_error: 13.8154
# Epoch 49/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.6356 - mean_absolute_error: 13.6356 - val_loss: 13.6881 - val_mean_absolute_error: 13.6881
# Epoch 50/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.6358 - mean_absolute_error: 13.6358 - val_loss: 13.7864 - val_mean_absolute_error: 13.7864
# Epoch 51/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.5927 - mean_absolute_error: 13.5927 - val_loss: 13.6470 - val_mean_absolute_error: 13.6470
# Epoch 52/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.5633 - mean_absolute_error: 13.5633 - val_loss: 13.7484 - val_mean_absolute_error: 13.7484
# Epoch 53/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 13.5251 - mean_absolute_error: 13.5251 - val_loss: 13.6438 - val_mean_absolute_error: 13.6438
# Epoch 54/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 13.5544 - mean_absolute_error: 13.5544 - val_loss: 13.6584 - val_mean_absolute_error: 13.6584
# Epoch 55/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.5034 - mean_absolute_error: 13.5034 - val_loss: 13.8265 - val_mean_absolute_error: 13.8265
# Epoch 56/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 13.5337 - mean_absolute_error: 13.5337 - val_loss: 13.6935 - val_mean_absolute_error: 13.6935
# Epoch 57/100
# 11248/11248 [==============================] - 0s 26us/step - loss: 13.4974 - mean_absolute_error: 13.4974 - val_loss: 13.6640 - val_mean_absolute_error: 13.6640
# Epoch 58/100
# 11248/11248 [==============================] - 0s 25us/step - loss: 13.4956 - mean_absolute_error: 13.4956 - val_loss: 13.6850 - val_mean_absolute_error: 13.6850
# Epoch 59/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.5095 - mean_absolute_error: 13.5095 - val_loss: 13.5959 - val_mean_absolute_error: 13.5959
# Epoch 60/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.4565 - mean_absolute_error: 13.4565 - val_loss: 13.6127 - val_mean_absolute_error: 13.6127
# Epoch 61/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.4650 - mean_absolute_error: 13.4650 - val_loss: 13.6161 - val_mean_absolute_error: 13.6161
# Epoch 62/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.4311 - mean_absolute_error: 13.4311 - val_loss: 13.8415 - val_mean_absolute_error: 13.8415
# Epoch 63/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.4406 - mean_absolute_error: 13.4406 - val_loss: 13.6377 - val_mean_absolute_error: 13.6377
# Epoch 64/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.4616 - mean_absolute_error: 13.4616 - val_loss: 13.7413 - val_mean_absolute_error: 13.7413
# Epoch 65/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.4074 - mean_absolute_error: 13.4074 - val_loss: 13.7393 - val_mean_absolute_error: 13.7393
# Epoch 66/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.4094 - mean_absolute_error: 13.4094 - val_loss: 13.7206 - val_mean_absolute_error: 13.7206
# Epoch 67/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.4490 - mean_absolute_error: 13.4490 - val_loss: 13.5981 - val_mean_absolute_error: 13.5981
# Epoch 68/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.4565 - mean_absolute_error: 13.4565 - val_loss: 13.6497 - val_mean_absolute_error: 13.6497
# Epoch 69/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.3927 - mean_absolute_error: 13.3927 - val_loss: 13.6917 - val_mean_absolute_error: 13.6917
# Epoch 70/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.4509 - mean_absolute_error: 13.4509 - val_loss: 13.6811 - val_mean_absolute_error: 13.6811
# Epoch 71/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.3679 - mean_absolute_error: 13.3679 - val_loss: 13.8081 - val_mean_absolute_error: 13.8081
# Epoch 72/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.3545 - mean_absolute_error: 13.3545 - val_loss: 13.6687 - val_mean_absolute_error: 13.6687
# Epoch 73/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.3546 - mean_absolute_error: 13.3546 - val_loss: 13.7307 - val_mean_absolute_error: 13.7307
# Epoch 74/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.3380 - mean_absolute_error: 13.3380 - val_loss: 13.6193 - val_mean_absolute_error: 13.6193
# Epoch 75/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.4077 - mean_absolute_error: 13.4077 - val_loss: 13.7160 - val_mean_absolute_error: 13.7160
# Epoch 76/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.3344 - mean_absolute_error: 13.3344 - val_loss: 13.7454 - val_mean_absolute_error: 13.7454
# Epoch 77/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.3645 - mean_absolute_error: 13.3645 - val_loss: 13.8502 - val_mean_absolute_error: 13.8502
# Epoch 78/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.3015 - mean_absolute_error: 13.3015 - val_loss: 13.7741 - val_mean_absolute_error: 13.7741
# Epoch 79/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.3612 - mean_absolute_error: 13.3612 - val_loss: 13.5723 - val_mean_absolute_error: 13.5723
# Epoch 80/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 13.2970 - mean_absolute_error: 13.2970 - val_loss: 13.6139 - val_mean_absolute_error: 13.6139
# Epoch 81/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.3181 - mean_absolute_error: 13.3181 - val_loss: 13.7159 - val_mean_absolute_error: 13.7159
# Epoch 82/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.3003 - mean_absolute_error: 13.3003 - val_loss: 13.6405 - val_mean_absolute_error: 13.6405
# Epoch 83/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.2992 - mean_absolute_error: 13.2992 - val_loss: 13.6625 - val_mean_absolute_error: 13.6625
# Epoch 84/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.3176 - mean_absolute_error: 13.3176 - val_loss: 13.5752 - val_mean_absolute_error: 13.5752
# Epoch 85/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.2549 - mean_absolute_error: 13.2549 - val_loss: 13.6837 - val_mean_absolute_error: 13.6837
# Epoch 86/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.2989 - mean_absolute_error: 13.2989 - val_loss: 13.8341 - val_mean_absolute_error: 13.8341
# Epoch 87/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 13.2870 - mean_absolute_error: 13.2870 - val_loss: 13.5944 - val_mean_absolute_error: 13.5944
# Epoch 88/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.2784 - mean_absolute_error: 13.2784 - val_loss: 13.6508 - val_mean_absolute_error: 13.6508
# Epoch 89/100
# 11248/11248 [==============================] - 0s 29us/step - loss: 13.3065 - mean_absolute_error: 13.3065 - val_loss: 13.5917 - val_mean_absolute_error: 13.5917
# Epoch 90/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.2532 - mean_absolute_error: 13.2532 - val_loss: 13.7004 - val_mean_absolute_error: 13.7004
# Epoch 91/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.2730 - mean_absolute_error: 13.2730 - val_loss: 13.8375 - val_mean_absolute_error: 13.8375
# Epoch 92/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.2184 - mean_absolute_error: 13.2184 - val_loss: 13.6874 - val_mean_absolute_error: 13.6874
# Epoch 93/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.2635 - mean_absolute_error: 13.2635 - val_loss: 13.7906 - val_mean_absolute_error: 13.7906
# Epoch 94/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.2123 - mean_absolute_error: 13.2123 - val_loss: 13.6373 - val_mean_absolute_error: 13.6373
# Epoch 95/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.2819 - mean_absolute_error: 13.2819 - val_loss: 13.6250 - val_mean_absolute_error: 13.6250
# Epoch 96/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.2316 - mean_absolute_error: 13.2316 - val_loss: 13.6454 - val_mean_absolute_error: 13.6454
# Epoch 97/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.2196 - mean_absolute_error: 13.2196 - val_loss: 13.5760 - val_mean_absolute_error: 13.5760
# Epoch 98/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.2424 - mean_absolute_error: 13.2424 - val_loss: 13.5618 - val_mean_absolute_error: 13.5618
# Epoch 99/100
# 11248/11248 [==============================] - 0s 28us/step - loss: 13.2083 - mean_absolute_error: 13.2083 - val_loss: 13.6119 - val_mean_absolute_error: 13.6119
# Epoch 100/100
# 11248/11248 [==============================] - 0s 27us/step - loss: 13.1914 - mean_absolute_error: 13.1914 - val_loss: 13.7167 - val_mean_absolute_error: 13.7167
# 2812/2812 [==============================] - 0s 23us/step
# Test Loss: 13.717
# Test MSE: 13.717

# %% [markdown]
# ### Curva de perdidas

# %%
# veamos nuestra curva de pérdidas
plt.plot(np.arange(0, n_epochs), history_callback.history["loss"])
plt.title("Training Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# A la vista de estos datos observamos una curva con muchas mas irregularidades y que tarda mas en converger.

# %% [markdown]
# ### Bondad del modelo

# %%
# Obtenemos la prediccion de nuestro modelo para los datos de Test
preds = model.predict(X_test)
 

# Calulamos la diferencia entre los precios predichos y los reales
# A continuacion calcularemos la diferencia porcentual y la diferecia absouta en porcentaje
diff = preds.flatten() - y_test
percentDiff = (diff / y_test) * 100
absPercentDiff = np.abs(percentDiff)
 

#Calculamos la media y la desviacion estandar
mean = np.mean(absPercentDiff)
std = np.std(absPercentDiff)
 
# Mostramos las estadisticas de nuestro modelo.
print("Precio medio de las pisos: {:.2f}€, Desviacion standar: {:.2f}€".format(
    full_airbnb["Price"].mean(), full_airbnb["Price"].std()))
print("Modelo --> mean: {:.2f}%, std: {:.2f}%".format(mean, std))
# Out:
# Precio medio de las pisos: 62.07€, Desviacion standar: 37.64€
# Modelo --> mean: 25.16%, std: 26.73%

# %%
history_callback.history["loss"]
